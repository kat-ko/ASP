# %% [markdown]
# # **Exercise 06. Logic programs with choice rules.**

# %% [markdown]
# #### **1**

# %%
# %%clingo -V0 0
# { a }.
# Out:
# a
# SATISFIABLE

# %% [markdown]
# **Note**: There is an empty line in the output. It represents the empty stable model.

# %%
# %%clingo -V0 0
# {a} :- b.
# b.

# %% [markdown]
# #### **2**

# %%
# %%clingo -V0 0
# { a }.
# b :- a.
# c :- not a.
# Out:
# c
# a b
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a }.
# b :- a.
# b :- not a.

# %% [markdown]
# #### **3**

# %%
# %%clingo -V0 0
# { a }.
# { b }.
# Out:
# a
# b
# b a
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a } :- c.
# { b } :- d.
# c.
# d :- c.

# %% [markdown]
# #### **4**

# %%
# %%clingo -V0 0
# { a }.
# { b } :- a.
# Out:
# a
# a b
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a }.
# { b } :- c.
# c :- a.

# %% [markdown]
# #### **5**

# %%
# %%clingo -V0 0
# { a }.
# { b } :- a.
# { c } :- not a.
# Out:
# c
# a
# a b
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a }.
# { b } :- d.
# { c } :- not d.
# d :- a.

# %% [markdown]
# #### **6**

# %%
# %%clingo -V0 0
# { a; b }.
# c :- not a, not b.
# d :- a, b.
# Out:
# c
# b
# a
# a b d
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a; b }.
# c :- not a, b.
# d :- a, not b.

# %% [markdown]
# #### **7**

# %%
# %%clingo -V0 0
# { a; b }.
# b :- a.
# a :- b.
# Out:
# a b
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a; b; c }.
# b :- a.
# a :- c.
# c :- b.

# %% [markdown]
# #### **8**

# %%
# %%clingo -V0 0
# { a; b }.
# b :- a.
# a :- b.
# { c } :- not a, not b.
# Out:
# c
# a b
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a; b }.
# b :- a.
# a :- b.
# { c } :- a, b.
