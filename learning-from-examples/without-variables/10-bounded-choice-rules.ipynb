# %% [markdown]
# # **Exercise 10. Bounded choice rules.**

# %% [markdown]
# #### **1**

# %%
# %%clingo -V0 0
# { a; b }.
# :- not 1 { a; b } 1.
# Out:
# b
# a
# SATISFIABLE

# %%
# %%clingo -V0 0
# 1 { a; b } 1.

# %% [markdown]
# #### **2**

# %%
# %%clingo -V0 0
# { a; b; c }.
# :- not 2 { a; b; c }.
# Out:
# b c
# a b c
# a c
# a b
# SATISFIABLE

# %%
# %%clingo -V0 0
# 2 { a; b; c }.

# %% [markdown]
# #### **3**

# %%
# %%clingo -V0 0
# { a; b }.
# :- not 1 { a; b } 1.
# { b; c }.
# :- not 1 { b; c } 1.
# Out:
# a c
# b
# SATISFIABLE

# %%
# %%clingo -V0 0
# 1 { a; b } 1.
# 1 { b; c } 1.

# %% [markdown]
# #### **4**

# %%
# %%clingo -V0 0
# { a; b }.
# :- not { a; b } 1.
# { b; c }.
# :- not 1 { b; c }.
# Out:
# c
# a c
# b
# b c
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a; b } 1.
# 1 { b; c }.

# %% [markdown]
# #### **5**

# %%
# %%clingo -V0 0
# 1 { a; b } 1.
# c :- a.
# d :- b.
# :- { c; d } 0.
# Out:
# d b
# c a
# SATISFIABLE

# %%
# %%clingo -V0 0
# 1 { a; b } 1.
# c :- a.
# d :- b.
# :- 1 { c ; d }.

# %% [markdown]
# #### **6**

# %%
# %%clingo -V0 0
# 1 { a; b }.
# 1 { c; d } 1 :- a.
# :- b, 2 { a; c; d }.
# Out:
# b
# a c
# a d
# SATISFIABLE

# %%
# %%clingo -V0 0
# 1 { a; b }.
# 1 { c; d } 1 :- a.
# :- not 2 { a; b; c; d }.

# %% [markdown]
# #### **7**

# %%
# %%clingo -V0 0
# { a; b } 1.
# 1 { b; c } :- a.
# Out:
# b
# a c
# SATISFIABLE

# %%
# %%clingo -V0 0
# 1 { a; b } 1.
# 1 { b; c } 1 :- a.

# %% [markdown]
# #### **8**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not c.
# Out:
# b
# SATISFIABLE
# -:2:10-11: info: atom does not occur in any rule head:
#   c

# %%
# %%clingo -V0 0
# 1 { a } 1 :- { b } 0.
# 1 { b } 1 :- { c } 0.
