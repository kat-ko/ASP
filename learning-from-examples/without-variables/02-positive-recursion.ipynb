# %% [markdown]
# # **Exercise 2. Recursion in positive logic programs.**

# %% [markdown]
# #### **1**

# %%
# %%clingo -V0 0
# a :- a.
# Out:
# SATISFIABLE

# %%
# %%clingo -V0 0
# a:- a, b.
# b.

# %% [markdown]
# #### **2**

# %%
# %%clingo -V0 0
# a :- b.
# b :- a.
# Out:
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- b, c.
# b :- a, c.
# c.

# %% [markdown]
# #### **3**

# %%
# %%clingo -V0 0
# a :- b.
# b :- a.
# b.
# Out:
# b a
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- b.
# b :- a.
# b :- c.
# c.

# %% [markdown]
# #### **4**

# %%
# %%clingo -V0 0
# a :- b.
# b :- a.
# b.
# c :- a.
# Out:
# b a c
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- b.
# b :- a.
# b.
# c :- a, b.
# d :- a, b, c.

# %% [markdown]
# #### **5**

# %%
# %%clingo -V0 0
# a :- b.
# b :- c.
# c :- a.
# Out:
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- b, d.
# b :- c, e.
# c :- a, e.
# d.
# e :- d.

# %% [markdown]
# #### **6**

# %%
# %%clingo -V0 0
# a :- b.
# b :- c.
# c :- a.
# d.
# c :- d.
# Out:
# b a c d
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- b, d.
# b :- c, d.
# c :- a, d.
# d.
# c :- d.

# %% [markdown]
# #### **7**

# %%
# %%clingo -V0 0
# a :- b.
# b :- a.
# c :- d.
# d :- c.
# Out:
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- b, c.
# b :- a, d.
# c :- d.
# d :- c.
# d.

# %% [markdown]
# #### **8**

# %%
# %%clingo -V0 0
# a :- b.
# b :- a.
# c :- d.
# d :- c.
# c.
# b :- d.
# Out:
# b a d c
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- b, c, d.
# b :- a, c, d.
# c :- d.
# d :- c.
# c.
# b :- d.
