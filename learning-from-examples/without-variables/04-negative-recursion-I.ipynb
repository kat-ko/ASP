# %% [markdown]
# # **Exercise 04. Negative recursion in normal logic programs (I).**
#
# You probably will not write this type of programs, but it is good to see them at least once.

# %% [markdown]
# #### **1**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# Out:
# b
# a
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a, c.
# c.

# %% [markdown]
# #### **2**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# c :- a.
# d :- b.
# Out:
# b d
# a c
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# c :- a, not b.
# c :- b, not a.

# %% [markdown]
# #### **3**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# b :- not c.
# Out:
# b
# SATISFIABLE
# -:3:10-11: info: atom does not occur in any rule head:
#   c

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# b :- c.
# c.

# %% [markdown]
# #### **4**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# b :- not c.
# c.
# Out:
# c b
# c a
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a, c.
# b :- not c.
# c :- not d.

# %% [markdown]
# #### **5**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# c :- not d.
# d :- not c.
# Out:
# d b
# d a
# c b
# c a
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a, e.
# c :- not d.
# d :- not c, f.
# e.
# f :- e.

# %% [markdown]
# #### **6**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# c :- not d.
# d :- not c.
# e :- a, c.
# f :- a, d.
# g :- b, c.
# h :- b, d.
# Out:
# d b h
# d a f
# c b g
# c a e
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not c.
# c :- not d.
# d :- not c.
# e :- a, c.
# e :- a, d.
# f :- not a, c.
# f :- b, not c.

# %% [markdown]
# #### **7**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# c :- a.
# d :- c.
# c :- d.
# Out:
# a c d
# b
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# c :- a.
# d :- c.
# c :- d.
# d :- b.

# %% [markdown]
# #### **8**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# c :- d.
# d :- c.
# a :- c, d.
# Out:
# b
# a
# SATISFIABLE

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not a.
# c :- d.
# d :- c.
# a :- c, d.
# c.
