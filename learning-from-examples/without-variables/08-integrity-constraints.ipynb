# %% [markdown]
# # **Exercise 8. Integrity constraints.**

# %% [markdown]
# #### **1**

# %%
# %%clingo -V0 0
# { a }.
# :- a.
# Out:
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a }.
# :- not a.

# %% [markdown]
# #### **2**

# %%
# %%clingo -V0 0
# { a }.
# b :- a.
# :- not b.
# Out:
# b a
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a }.
# b :- not a.
# :- b.

# %% [markdown]
# #### **3**

# %%
# %%clingo -V0 0
# { a }.
# b :- a.
# c :- not a.
# :- a, b.
# :- not a, c.
# Out:
# UNSATISFIABLE

# %%
# %%clingo -V0 0
# { a }.
# b :- not a.
# c :- a.
# :- not a, not b.
# :- a, c.

# %% [markdown]
# #### **4**

# %%
# %%clingo -V0 0
# { a; b }.
# c :- a, not b.
# d :- not a, b.
# :- c.
# :- d.
# Out:
# a b
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a; b }.
# :- a, not b.
# :- not a, b.

# %% [markdown]
# #### **5**

# %%
# %%clingo -V0 0
# { a } :- b.
# { b } :- c.
# { c } :- a.
# { a }.
# :- a, c.
# Out:
# a
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a } :- b, c.
# { b } :- c.
# { c } :- a.
# { c }.
# :- not a.

# %% [markdown]
# #### **6**

# %%
# %%clingo -V0 0
# { a; b; c }.
# :- a, not b.
# :- not a, c.
# :- b, not c.
# Out:
# a b c
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a; b; c }.
# :- not a, b.
# :- a, not c.
# :- not b, c.

# %% [markdown]
# #### **7**

# %%
# %%clingo -V0 0
# { a; b }.
# a :- b.
# b :- a.
# :- a, b.
# Out:
# SATISFIABLE

# %%
# %%clingo -V0 0
# { a; b }.
# :- not a, b.
# :- not b, a.
# :- a, b.

# %% [markdown]
# #### **8**

# %%
# %%clingo -V0 0
# a :- not b.
# b :- not c.
# Out:
# b
# SATISFIABLE
# -:2:10-11: info: atom does not occur in any rule head:
#   c

# %%
# %%clingo -V0 0
# { a } :- not b.
# :- not a, not b.
# { b } :- not c.
# :- not b, not c.

# %% [markdown]
# #### **9**

# %%
# %%clingo -V0 0
# :- not a.
# Out:
# UNSATISFIABLE
# -:1:8-9: info: atom does not occur in any rule head:
#   a

# %%
# %%clingo -V0 0
# :- not a.
# a.

# %% [markdown]
# #### **10**

# %%
# %%clingo -V0 0
# :-.
# Out:
# UNSATISFIABLE

# %%
# %%clingo -V0 0
# :-.
# a.
